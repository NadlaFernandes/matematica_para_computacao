# %%
# Meu primeiro programa em python

from matplotlib import pyplot as plt
x = []
y = [] 
z = []
for i in range(0,10):
    x.append(i)
    y.append(x[i]*x[i])
    z.append(2*x[i])
    
plt.plot(x,y)
plt.plot(x,z)
plt.grid()
